# %% [markdown]
# # Real-world Data Wrangling

# %% [markdown]
# In this project, you will apply the skills you acquired in the course to gather and wrangle real-world data with two datasets of your choice.
#
# You will retrieve and extract the data, assess the data programmatically and visually, accross elements of data quality and structure, and implement a cleaning strategy for the data. You will then store the updated data into your selected database/data store, combine the data, and answer a research question with the datasets.
#
# Throughout the process, you are expected to:
#
# 1. Explain your decisions towards methods used for gathering, assessing, cleaning, storing, and answering the research question
# 2. Write code comments so your code is more readable

# %%
#Installing Packages
# !python -m pip install kaggle==1.6.12
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.7/79.7 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 12.4 MB/s eta 0:00:00
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.12-py3-none-any.whl size=102969 sha256=88433aa959c76955553cb34cad5d06760075ed3f52aabb927c6d3a46eb3512ae
#   Stored in directory: /home/student/.cache/pip/wheels/1e/0b/7c/50f8e89c3d2f82838dbd7afeddffbb9357003009ada98216c7
# Successfully built kaggle
# ...
#   WARNING: The script slugify is installed in '/home/student/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script kaggle is installed in '/home/student/.local/bin' which is not on PATH.
# ...

# %%
# !pip install --target=/workspace ucimlrepo
# Out:
# ...
#   Using cached ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# ...
#   Using cached pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
# ...
#   Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 92.0 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.11.2 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.2.6 which is incompatible.
# ...
# WARNING: Target directory /workspace/dateutil already exists. Specify --upgrade to force replacement.
# ...

# %%
import sys
# !{sys.executable} -m pip install fsspec
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import sys
# !{sys.executable} -m pip install huggingface_hub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ## 1. Gather data
#
# In this section, you will extract data using two different data gathering methods and combine the data. Use at least two different types of data-gathering methods.

# %% [markdown]
# ### **1.1.** Problem Statement
# I am looking at the coorelation between salary and demand for jobs in the data science field. Specifically, what roles are the highest paid and which are the top 5 most in demand.

# %% [markdown]
# Finding the right datasets can be time-consuming. Here we provide you with a list of websites to start with. But we encourage you to explore more websites and find the data that interests you.
#
# * Google Dataset Search https://datasetsearch.research.google.com/
# * The U.S. Government’s open data https://data.gov/
# * UCI Machine Learning Repository https://archive.ics.uci.edu/ml/index.php

# %% [markdown]
# ### **1.2.** Gather at least two datasets using two different data gathering methods
#
# List of data gathering methods:
#
# - Download data manually
# - Programmatically downloading files
# - Gather data by accessing APIs
# - Gather and extract data from HTML files using BeautifulSoup
# - Extract data from a SQL database
#
# Each dataset must have at least two variables, and have greater than 500 data samples within each dataset.
#
# For each dataset, briefly describe why you picked the dataset and the gathering method (2-3 full sentences), including the names and significance of the variables in the dataset. Show your work (e.g., if using an API to download the data, please include a snippet of your code).
#
# Load the dataset programmtically into this notebook.

# %% [markdown]
# #### **Dataset 1** Job Salaries
#
# Type:  CSV File
#
# Method: The data was gathered by programatically downloading the file from the hugginglearners repository.
#
# Dataset variables:
#
# * work_year: year salary was paid
# * experience_level: level of experience for role (entry-level, mid-level, etc)
# * employment_type: type of employement (part-time, full-time)
# * job_title: specific job role help by employee
# * salary: gross salary paid out
# * salary_currency: currency the salary was paid in represented by currency code
# * salary_in_usd: salary amount converted to USD using standard exchange rate for comparison.
# * employee_residence: primary country of employee using country codes
# * remote_ratio: proportion of work that can be done remotely
# * company_location: country of the main office or contracting branch using country codes
# * company_size: size of company based on average number of employees in categories

# %%
#FILL IN 1st data gathering and loading method
import pandas as pd
# !pip install "fsspec[http]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
salary = pd.read_csv("hf://datasets/hugginglearners/data-science-job-salaries/ds_salaries.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /workspace/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /opt/conda/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'fsspec'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
salary.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 salary.head()
#
# NameError: name 'salary' is not defined

# %% [markdown]
# #### Dataset 2 - Glassdoor Jobs
#
# Type: CSV
#
# Method: The data was gathered by manual csv download.
#
# Dataset variables:
#
# * Job Title: position
# * Salary Estimate: salary details
# * Job Description: summary of role
# * Rating: company or job rating
# * Company Name: company identifier
# * Location: job location
# * Size: company size
# * Founded: year of founding
# * Type of Ownership: description of ownership type
# * Industry: categorization of activity field
# * Sector: classification of industry
# * Revenue: revenue scale of company

# %%
jobs = pd.read_csv("glassdoor_jobs.csv")
jobs.head()

# %% [markdown]
# Optional data storing step: You may save your raw dataset files to the local data store before moving to the next step.

# %%
#Optional: store the raw data in your local data store
# Create directories if they don't exist
os.makedirs('raw data', exist_ok=True)
salary.to_csv('raw data/salary_raw.csv', index=False)
jobs.to_csv('raw data/jobs_raw.csv', index=False)

# %% [markdown]
# ## 2. Assess data
#
# Assess the data according to data quality and tidiness metrics using the report below.
#
# List **two** data quality issues and **two** tidiness issues. Assess each data issue visually **and** programmatically, then briefly describe the issue you find.  **Make sure you include justifications for the methods you use for the assessment.**

# %% [markdown]
# ### Quality Issue 1: Data Completeness

# %%
# Inspecting the dataframe visually 
## Several rows have missing values. These are marked by a "-1" and will create issues in transforming the data. 
jobs.sample(10)

# %%
#Inspecting the dataframe programmatically
##

# %%
#FILL IN - Inspecting the dataframe programmatically
missing_S = jobs[jobs["Salary Estimate"] == "-1"].shape[0]
missing_R = jobs[jobs["Rating"] == -1].shape[0]
missing_F = jobs[jobs["Founded"] == -1].shape[0]
missing_I = jobs[jobs["Industry"] == "-1"].shape[0]
missing_SE = jobs[jobs["Sector"] == "-1"].shape[0]


print("Number of salaries missing "+str(missing_S))
print("Number of ratings missing "+str(missing_R))
print("Number of founding years missing "+str(missing_F))
print("Number of industries missing "+str(missing_I))
print("Number of sectors missing "+str(missing_SE))
##to see if there is null values

# %% [markdown]
# Issue and justification: There is significant missing data in several key columns. Where these values are missing, a "-1" is included, which could skew the analysis and data transformation.

# %% [markdown]
# ### Quality Issue 2: Duplication

# %%
#Inspecting the dataframe visually

# %%
jobs.sample(20)

# %%
#Inspecting the dataframe programmatically

# %%
jobs.duplicated().sum()

# %% [markdown]
# Issue and justification: There are 680 duplicate values in this dataset. This can impact calculations done on the data and must be removed to get accurate results.

# %% [markdown]
# ### Tidiness Issue 1: Unnecessary Columns

# %%
#Inspecting the dataframe visually

# %%
salary.head()

# %%
#Inspecting the dataframe programmatically

# %%
salary.columns

# %% [markdown]
# Issue and justification: Unnamed: 0 is an index column that is unnecessary for our analysis. For the purpose of our analysis here, we only need the Salary in USD column so we can remove Salary and Salary Currency columns.

# %% [markdown]
# ### Tidiness Issue 2: Multiple Values present in a column

# %%
#Inspecting the dataframe visually

# %%
jobs.sample(5)

# %%
#FILL IN - Inspecting the dataframe programmatically

# %% [markdown]
# Issue and justification: Several columns have a range of data provided, such as salary, size, and revenue. This makes it difficult to analyze, so additional columns could be added with min/max salary or revenue buckets.

# %% [markdown]
# ## 3. Clean data
# Clean the data to solve the 4 issues corresponding to data quality and tidiness found in the assessing step. **Make sure you include justifications for your cleaning decisions.**
#
# After the cleaning for each issue, please use **either** the visually or programatical method to validate the cleaning was succesful.
#
# At this stage, you are also expected to remove variables that are unnecessary for your analysis and combine your datasets. Depending on your datasets, you may choose to perform variable combination and elimination before or after the cleaning stage. Your dataset must have **at least** 4 variables after combining the data.

# %%
# FILL IN - Make copies of the datasets to ensure the raw dataframes 
# are not impacted
salary_dup = salary.copy()
jobs_dup = jobs.copy()

# %% [markdown]
# ### **Quality Issue 1: Duplicate Values**

# %%
# FILL IN - Apply the cleaning strategy
jobs_dup = jobs_dup.drop_duplicates()

# %%
# FILL IN - Validate the cleaning was successful

# %% [markdown]
# Justification: *FILL IN*

# %% [markdown]
# ### **Quality Issue 2: FILL IN**

# %%
#FILL IN - Apply the cleaning strategy
## replacing the -1 values with NaNs
jobs_dup.replace('-1', np.nan, inplace=True)
jobs_dup.replace(-1, np.nan, inplace=True)

jobs_dup=jobs_dup.dropna()
##dropping the null values

# %%
#FILL IN - Validate the cleaning was successful
print(jobs_dup.isna().sum().sum())
jobs_dup.sample(10)

# %% [markdown]
# Justification: *FILL IN*

# %% [markdown]
# ### **Tidiness Issue 1: Unnecessary Columns**

# %%
#FILL IN - Apply the cleaning strategy
salary_dup= salary_dup[["work_year" , "experience_level", "employment_type", "job_title","salary_in_usd","employee_residence","remote_ratio","company_location","company_size"]]
##removing the salary and salary_currency columns

# %%
#FILL IN - Validate the cleaning was successful
salary_dup.head()

# %% [markdown]
# Justification: Removed salary and salary currency columns ensure the data is simpler to read and understand.

# %% [markdown]
# ### **Tidiness Issue 2: Value ranges in one column**

# %%
#FILL IN - Apply the cleaning strategy

# %%
import pandas as pd
import re


# Function to extract min and max salaries
def extract_salaries(salary_estimate):
    if pd.isna(salary_estimate):
        return pd.Series([None, None])
    
    # Use regex to extract salaries and remove non-numeric characters except dash and K
    match = re.findall(r'(\d+𝐾|\d+K)', salary_estimate)
    
    if len(match) == 2:
        min_salary = match[0].replace('K', '').replace('𝐾', '').strip()
        max_salary = match[1].replace('K', '').replace('𝐾', '').strip()
        
        # Convert to numeric values (thousands)
        min_salary = float(min_salary) 
        max_salary = float(max_salary)
        
        return pd.Series([min_salary, max_salary])
    else:
        return pd.Series([None, None])

# %%
jobs_dup[['min_salary', 'max_salary']] = jobs_dup['Salary Estimate'].apply(extract_salaries)

# %%
jobs_dup = jobs_dup.drop(columns="Salary Estimate")

# %%
jobs_dup = jobs_dup[[
    'Job Title', 'min_salary', 'max_salary', 'Job Description', 'Rating', 
    'Company Name', 'Location', 'Size', 'Founded', 
    'Type of ownership', 'Industry', 'Sector', 'Revenue'
]]

# %%
#FILL IN - Validate the cleaning was successful
jobs_dup.head()

# %% [markdown]
# Justification: Seperating columns from ranges into min and max ensures ease of reading the data and potential for addition analysis such as highest or lowest paying positions.

# %% [markdown]
# ### **Remove unnecessary variables and combine datasets**
#
# Depending on the datasets, you can also peform the combination before the cleaning steps.

# %%
#FILL IN - Remove unnecessary variables and combine datasets
salary_final = salary_dup[["work_year","experience_level","employment_type","job_title","salary_in_usd","remote_ratio"]]
jobs_final = jobs_dup[["Job Title","min_salary","max_salary","Rating","Company Name","Size"]]

combined_final = pd.concat([salary_final, jobs_final], axis=1)

# %% [markdown]
# ## 4. Update your data store
# Update your local database/data store with the cleaned data, following best practices for storing your cleaned data:
#
# - Must maintain different instances / versions of data (raw and cleaned data)
# - Must name the dataset files informatively
# - Ensure both the raw and cleaned data is saved to your database/data store

# %%
#FILL IN - saving data
os.makedirs('cleaned final', exist_ok=True)
salary_dup.to_csv('cleaned final/salary_dup_final.csv',index=False)
jobs_dup.to_csv('cleaned final/jobs_dup_final.csv', index=False)
combined_final.to_csv('cleaned final/combined_final.csv')

# %% [markdown]
# ## 5. Answer the research question
#
# ### **5.1:** Define and answer the research question
# Going back to the problem statement in step 1, use the cleaned data to answer the question you raised. Produce **at least** two visualizations using the cleaned data and explain how they help you answer the question.

# %% [markdown]
# *Research question:* In USD, which role pays the highest?

# %%
#Visual 1 - FILL IN
import matplotlib.pyplot as plt


salary_dup.groupby("job_title")["salary_in_usd"].mean().plot(kind="bar", figsize=(15, 10))

# %% [markdown]
# *Answer to research question:* The role that pays the highest is Data Analytics Lead.

# %% [markdown]
# *Research question:* Which role is in the highest demand?

# %%
#Visual 2 - FILL IN
job_counts = jobs_dup['Job Title'].value_counts()

# Select top 10 job titles
top_5_jobs = job_counts.head(5)


plt.figure(figsize=(10, 8))
top_5_jobs.plot(kind='bar')
plt.title('Top 5 Most Wanted Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# *Answer to research question:* The role in the highest demand is Data Scientist.

# %% [markdown]
# ### **5.2:** Reflection

# %% [markdown]
# *Answer:* If there was more time to work on this project, I would do additional transformation on role titles and other data quality issues. I would also do additional analysis on salary by location, experience levels, and titles to see patterns for future career decisions. I would be interested to see if there is a plateau of experience or education that could cap that salary, or what the highest salary for lowest education or experience would look like.
